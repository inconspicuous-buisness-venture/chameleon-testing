# %%
human_text = [
    """
    He first outlines social timing, or engagement with users, particularly in vehicles. He notes that varying levels of driver engagement can deeply influence the driver's safety. He notes the PASS system, which defines if ‘now is a good time’ to tell the user information. This is identified with a series of external cameras, vehicle states, internal cameras, and biosensors. In essence, the system accounts for contextual and human factors. By using the INAGT Dataset and the PazNet Multi-Sensor Fusion Network, the lab was able to take multiple different media channels to make predictions. The image channel uses I3D Inception Feature Extraction, and the physiological channels use convolution and subsampling to output a series of values. All these channels are concatenated to deduce if it is safe to communicate with the user. He notes that the model performs well, but he also mentions that directly adjusting the loss function can eliminate and prevent any annoying or unsafe interruptions. He also suggests that extra sensing adds significant value to the accuracy of the prediction. 
    """, 
    """
    Dr. Oritz begins by describing the applications of multimodal learning, noting that it allows for more accurate identification of phenomena, as well as more “textured interactivity, ” a nuanced and more natural interaction with people. He notes that sensing devices are ubiquitous, described as “ubiquitous sensing and computation.” However, he explains that these sensors can be applied to learning and interaction. When explaining the definition of multimodality, he refers to a distinct type of information or signal that can account for diversity or variability in the types of data or modalities being processed or integrated. In essence, multimodality can only be achieved by translating multiple types of media into a single space. Some of the multimodal applications could be vehicular agents, smart offices, urban sensing, and human-robot interaction. 
    """,
    """
    He then begins to explain multimodal learning applications for robot feeding during social dining. He uses a series of microphones and cameras to train a model that identifies if a user intends to take a bite of food in a situation. This will then be transferred to a robot, which will automatically feed the user. These modalities are then passed into the algorithm with interleaved links between channels, which were able to catch correlated actions between diners. However, he also notes that with no other individuals, there are no social cues or interactions, which makes the identification of user intent much more difficult. They then compressed the model and ran it on a real machine, which was able to feed users simply by allowing them to expect to be fed naturally. The accuracy of the model was able to achieve scores upwards of 98 percent. However, some were much lower, scoring only 77 percent accuracy. However, the accuracy of the model increased as the number of diners increased. 
    """,
    """
    Finally, he describes the potential of smart office sensors, which small Raspberry Pis can power. Simply by having accelerometers, sound, temperature, humidity, light, and a few other sensors, certain events can be accurately predicted using machine learning by taking a series of different signals. This is fed into a new model called the GeXSe, or a generative explanatory sensor system, which is able to take multiple types of data in order to make predictions as to what is happening in the scene. This could be very powerful in identifying different types of events, especially in safety and security. 
    """
]

ai_text = [
    """
    He begins by discussing social timing, focusing on user engagement, especially in vehicles. He highlights how varying levels of driver involvement can significantly affect safety. He introduces the PASS system, which determines whether “now is a good time” to share information with the user. This is achieved through external cameras, vehicle states, internal cameras, and biosensors. Essentially, the system integrates contextual and human factors. Utilizing the INAGT Dataset and PazNet Multi-Sensor Fusion Network, the lab combines various media channels to make predictions. The image channel uses I3D Inception for feature extraction, while physiological channels employ convolution and subsampling to generate values. These channels are then merged to decide if communication is safe. He states the model performs well but notes that adjusting the loss function directly can prevent annoying or unsafe interruptions. He also emphasizes that adding extra sensing greatly improves prediction accuracy.
    """, 
    """
    Dr. Ortiz begins by discussing the uses of multimodal learning, highlighting its ability to more accurately identify phenomena and enable “textured interactivity,” a refined and more natural way of engaging with people. He observes that sensing devices are prevalent, described as “ubiquitous sensing and computation.” However, he explains that these sensors can support learning and interaction. While defining multimodality, he mentions it as a distinct type of information or signal that accounts for diversity or variability in the data or modalities being processed or integrated. Essentially, multimodality is achieved by converting various types of media into a unified space. Examples of multimodal applications include vehicular agents, smart offices, urban sensing, and human-robot interaction.
    """,
    """
    He then describes multimodal learning applications for robot feeding during social dining. Using a combination of microphones and cameras, he trains a model to detect when a user intends to take a bite of food in a given scenario. This information is then relayed to a robot that automatically feeds the user. The modalities are processed through an algorithm with interleaved links between channels, enabling it to capture correlated actions among diners. However, he notes that in the absence of other individuals, the lack of social cues makes it significantly harder to identify user intent. The team then compressed the model and tested it on a real machine, which successfully fed users by enabling them to expect natural feeding interactions. The model achieved accuracy scores as high as 98 percent, though some instances scored as low as 77 percent. Interestingly, the model’s accuracy improved as the number of diners increased.
    """,
    """
    Finally, he outlines the potential of smart office sensors, which can be powered by small Raspberry Pis. By utilizing accelerometers, sound, temperature, humidity, light, and other sensors, certain events can be accurately predicted through machine learning by analyzing a combination of signals. This data is processed through a new model called GeXSe, or generative explanatory sensor system, which integrates multiple data types to predict what is occurring in a given scene. This system shows great promise for identifying various events, particularly in safety and security contexts.
    """
]

# %%
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns

# Function to compute word frequencies
def get_word_frequencies(text):
    words = text.lower().split()
    word_counts = Counter(words)
    return list(word_counts.values())

# Function to overlay KDE plots
def overlay_kde_plots(human_texts, ai_texts, title):
    plt.figure(figsize=(10, 6))
    
    # Human plots in red
    for i, text in enumerate(human_texts):
        freq_values = get_word_frequencies(text)
        sns.kdeplot(freq_values, fill=True, color=plt.cm.Reds(i / len(ai_texts)), alpha=0, label=f'Human {i + 1}')
    
    # AI plots in blue
    for i, text in enumerate(ai_texts):
        freq_values = get_word_frequencies(text)
        sns.kdeplot(freq_values, fill=True, color=plt.cm.Blues(i / len(ai_texts)), alpha=0, label=f'AI {i + 1}')
    
    # Add title, labels, and legend
    plt.title(title)
    plt.xlabel('Frequency')
    plt.ylabel('Density')
    plt.legend()
    plt.show()

overlay_kde_plots(human_text, ai_text, 'KDE of Word Frequencies for Humans and AI')
